# %% [markdown]
# # Changing Datatype

# %%
import numpy as np

# %%
a = np.arange(8).reshape(2,2,2)
a
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
# astype

a.astype(np.float16)
# Out:
# array([[[0., 1.],
#         [2., 3.]],
#
#        [[4., 5.],
#         [6., 7.]]], dtype=float16)
