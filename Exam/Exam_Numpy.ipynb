# %% [markdown]
# # 🏢 Industry-Standard NumPy Questions
# ### *(Data Analysis & Data Science)*
#
# ---
#
# ## 🔹 Section 1: Core NumPy Fundamentals (Q1–Q10)
#
# 1. Why is NumPy significantly faster than Python lists for numerical computation?
# 2. Create a NumPy array containing values from 0 to 1,000 with a step size of 5.
# 3. Explain the difference between `np.array()` and `np.asarray()`.
# 4. How does NumPy store data in memory, and why does this matter for performance?
# 5. Create a 3×5 NumPy array of random integers between 100 and 500.
# 6. What is the purpose of NumPy data types (`dtype`)?
# 7. Convert a float array into an integer array and analyze the impact on memory.
# 8. How do you check the shape, size, and number of dimensions of a NumPy array?
# 9. Create an identity matrix of size 6×6.
# 10. When should you explicitly specify the `dtype` while creating a NumPy array?
#
# ---
#
# ## 🔹 Section 2: Indexing, Slicing & Masking (Q11–Q20)
#
# 11. Extract the last column from a 2D NumPy array.
# 12. Reverse a NumPy array without using loops.
# 13. Explain boolean indexing and its importance in data analysis.
# 14. Select all values greater than the mean of an array.
# 15. Replace all negative values in an array with zero.
# 16. Extract rows where total sales exceed a given threshold.
# 17. What is fancy indexing and how is it different from slicing?
# 18. Select elements at indices `[2, 5, 8, 11]` from a NumPy array.
# 19. Demonstrate the difference between a view and a copy in NumPy.
# 20. How do you apply multiple conditions when filtering a NumPy array?
#
# ---
#
# ## 🔹 Section 3: Mathematical & Statistical Operations (Q21–Q30)
#
# 21. Compute the mean, median, and standard deviation of a dataset using NumPy.
# 22. Calculate row-wise and column-wise sums of a 2D array.
# 23. What is the difference between `np.sum()` and `np.cumsum()`?
# 24. Normalize a NumPy array using Min-Max normalization.
# 25. Compute variance and covariance using NumPy.
# 26. Find the minimum and maximum values in each column of a dataset.
# 27. Calculate the correlation coefficient between two NumPy arrays.
# 28. Explain the use of `np.argmax()` and `np.argmin()` in analytics.
# 29. Round all values in a NumPy array to two decimal places.
# 30. Perform Z-score normalization on a dataset.
#
# ---
#
# ## 🔹 Section 4: Shape Manipulation & Broadcasting (Q31–Q40)
#
# 31. Explain NumPy broadcasting rules with an example.
# 32. Reshape a 1D NumPy array of size 60 into a 6×10 matrix.
# 33. What is the difference between `reshape()` and `resize()`?
# 34. Flatten a 3D NumPy array into a 1D array.
# 35. Stack two arrays vertically and horizontally.
# 36. Split a NumPy array into four equal parts.
# 37. Explain the role of the `axis` parameter in NumPy functions.
# 38. Expand the dimensions of a 1D array to make it column-wise.
# 39. Remove single-dimensional entries from an array.
# 40. Transpose a 2D feature matrix.
#
# ---
#
# ## 🔹 Section 5: Data Science & Real-World Scenarios (Q41–Q50)
#
# 41. Detect and count missing values (`NaN`) in a NumPy array.
# 42. Replace missing values with the mean of the dataset.
# 43. Identify outliers in a dataset using statistical methods.
# 44. Generate a dataset following a normal distribution.
# 45. Simulate rolling a six-sided dice 10,000 times and analyze outcomes.
# 46. Explain how vectorization improves performance in NumPy.
# 47. Compare `np.copy()` and `np.view()` with a real-world use case.
# 48. Compute a moving average for time-series data using NumPy.
# 49. Perform matrix multiplication using NumPy’s linear algebra tools.
# 50. Describe a real-world data science problem where NumPy is preferred over Pandas.
